# %%
import pandas as pd

# %%
# dataset = files.upload()
# Out:
#      <input type="file" id="files-fe114ac8-b5de-4196-8376-a2c2379b2209" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe114ac8-b5de-4196-8376-a2c2379b2209">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("training_data.csv")

# %%
df.isnull().sum()
# Out:
# itching                    0
# skin_rash                  0
# nodal_skin_eruptions       0
# continuous_sneezing        0
# shivering                  0
#                         ...
# blister                    0
# red_sore_around_nose       0
# yellow_crust_ooze          0
# prognosis                  0
# Unnamed: 133            4920
# Length: 134, dtype: int64

# %%
df.drop(columns="Unnamed: 133",inplace = True)

# %%
x = df.drop(columns="prognosis")

# %%
y = df["prognosis"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_p_train = rf.predict(x_train)

# %%
y_p_test = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train,y_p_train)
# Out:
# 1.0

# %%
accuracy_score(y_test,y_p_test)
# Out:
# 1.0

# %%
for i in df:
  print(i)
# Out:
# itching
# skin_rash
# nodal_skin_eruptions
# continuous_sneezing
# shivering
# chills
# joint_pain
# stomach_pain
# acidity
# ulcers_on_tongue
# muscle_wasting
# vomiting
# burning_micturition
# spotting_ urination
# fatigue
# weight_gain
# anxiety
# cold_hands_and_feets
# mood_swings
# weight_loss
# restlessness
# lethargy
# patches_in_throat
# irregular_sugar_level
# cough
# high_fever
# sunken_eyes
# breathlessness
# sweating
# dehydration
# indigestion
# headache
# yellowish_skin
# dark_urine
# nausea
# loss_of_appetite
# pain_behind_the_eyes
# back_pain
# constipation
# abdominal_pain
# diarrhoea
# mild_fever
# yellow_urine
# yellowing_of_eyes
# acute_liver_failure
# fluid_overload
# swelling_of_stomach
# swelled_lymph_nodes
# malaise
# blurred_and_distorted_vision
# phlegm
# throat_irritation
# redness_of_eyes
# sinus_pressure
# runny_nose
# congestion
# chest_pain
# weakness_in_limbs
# fast_heart_rate
# pain_during_bowel_movements
# pain_in_anal_region
# bloody_stool
# ...

# %%
input1 = input("You have a itching :")
input2 = input("You have a skin rash :")
input3 = input("You have a nodal skin eruptions :")
input4 = input("You have a continuous sneezing :")
input5 = input("You have a shivering :")
input6 = input("You have a chills :")
input7 = input("You have a joint pain :")
input8 = input("You have a stomach pain :")
input9 = input("You have a acidity :")
input10 = input("You have a ulcers on tongue :")
input11 = input("You have a muscle wasting :")
input12 = input("You have a vomiting :")
input13 = input("You have a burning micturition :")
input14 = input("You have a spotting_urination :")
input15 = input("You have a fatigue :")
input16 = input("You have a weight_gain :")
input17 = input("You have a anxiety :")
input18 = input("You have a cold_hands_and_feets :")
input19 = input("You have a mood_swings :")
input20 = input("You have a weight_loss :")
input21 = input("You have a restlessness :")
input22 = input("You have a lethargy :")
input23 = input("You have a patches_in_throat :")
input24 = input("You have a irregular_sugar_level :")
input25 = input("You have a cough :")
input26 = input("You have a high_fever :")
input27 = input("You have a sunken_eyes :")
input28 = input("You have a breathlessness :")
input29 = input("You have a sweating :")
input30 = input("You have a dehydration :")
input31 = input("You have a indigestion :")
input32 = input("You have a headache :")
input33 = input("You have a yellowish_skin :")
input34 = input("You have a dark_urine :")
input35 = input("You have a nausea :")
input36 = input("You have a loss_of_appetite :")
input37 = input("You have a pain_behind_the_eyes :")
input38 = input("You have a back_pain :")
input39 = input("You have a constipation :")
input40 = input("You have a abdominal_pain :")
input41 = input("You have a diarrhoea :")
input42 = input("You have a mild_fever :")
input43 = input("You have a yellow_urine :")
input44 = input("You have a yellowing_of_eyes :")
input45 = input("You have a acute_liver_failure :")
input46 = input("You have a fluid_overload :")
input47 = input("You have a swelling_of_stomach :")
input48 = input("You have a swelled_lymph_nodes :")
input49 = input("You have a malaise :")
input50 = input("You have a blurred_and_distorted_vision :")
input51 = input("You have a phlegm :")
input52 = input("You have a throat_irritation :")
input53 = input("You have a redness_of_eyes :")
input54 = input("You have a sinus_pressure :")
input55 = input("You have a runny_nose :")
input56 = input("You have a congestion :")
input57 = input("You have a chest_pain :")
input58 = input("You have a weakness_in_limbs :")
input59 = input("You have a fast_heart_rate :")
input60 = input("You have a pain_during_bowel_movements :")
input61 = input("You have a pain_in_anal_region :")
input62 = input("You have a bloody_stool :")
input63 = input("You have a irritation_in_anus :")
input64 = input("You have a neck_pain :")
input65 = input("You have a dizziness :")
input66 = input("You have a cramps :")
input67 = input("You have a bruising :")
input68 = input("You have a obesity :")
input69 = input("You have a swollen_legs :")
input70 = input("You have a swollen_blood_vessels :")
input71 = input("You have a puffy_face_and_eyes :")
input72 = input("You have a enlarged_thyroid :")
input73 = input("You have a brittle_nails :")
input74 = input("You have a swollen_extremeties :")
input75 = input("You have a excessive_hunger :")
input76 = input("You have a extra_marital_contacts :")
input77 = input("You have a drying_and_tingling_lips :")
input78 = input("You have a slurred_speech :")
input79 = input("You have a knee_pain :")
input80 = input("You have a hip_joint_pain :")
input81 = input("You have a muscle_weakness :")
input82 = input("You have a stiff_neck :")
input83 = input("You have a swelling_joints :")
input84 = input("You have a movement_stiffness :")
input85 = input("You have a spinning_movements :")
input86 = input("You have a loss_of_balance :")
input87 = input("You have a unsteadiness :")
input88 = input("You have a weakness_of_one_body_side :")
input89 = input("You have a loss_of_smell :")
input90 = input("You have a bladder_discomfort :")
input91 = input("You have a foul_smell_of_urine :")
input92 = input("You have a continuous_feel_of_urine :")
input93 = input("You have a passage_of_gases :")
input94 = input("You have a internal_itching :")
input95 = input("You have a toxic_look_(typhos) :")
input96 = input("You have a depression :")
input97 = input("You have a irritability :")
input98 = input("You have a muscle_pain :")
input99 = input("You have a altered_sensorium :")
input100 = input("You have a red_spots_over_body :")
input101 = input("You have a belly_pain :")
input102 = input("You have a abnormal_menstruation :")
input103 = input("You have a dischromic _patches :")
input104 = input("You have a watering_from_eyes :")
input105 = input("You have a increased_appetite :")
input106 = input("You have a polyuria :")
input107 = input("You have a family_history :")
input108 = input("You have a mucoid_sputum :")
input109 = input("You have a rusty_sputum :")
input110 = input("You have a lack_of_concentration :")
input111 = input("You have a visual_disturbances :")
input112 = input("You have a receiving_blood_transfusion :")
input113 = input("You have a receiving_unsterile_injections :")
input114 = input("You have a coma :")
input115 = input("You have a stomach_bleeding :")
input116 = input("You have a distention_of_abdomen :")
input117 = input("You have a history_of_alcohol_consumption :")
input118 = input("You have a fluid_overload :")
input119 = input("You have a blood_in_sputum :")
input120 = input("You have a prominent_veins_on_calf :")
input121 = input("You have a palpitations :")
input122 = input("You have a painful_walking :")
input123 = input("You have a pus_filled_pimples :")
input124 = input("You have a blackheads :")
input125 = input("You have a scurring :")
input126 = input("You have a skin_peeling :")
input127 = input("You have a silver_like_dusting :")
input128 = input("You have a small_dents_in_nails :")
input129 = input("You have a inflammatory_nails :")
input130 = input("You have a blister :")
input131 = input("You have a red_sore_around_nose :")
input132 = input("You have a yellow_crust_ooze :")
# Out:
# You have a itching : 0
# You have a skin rash : 0
# You have a nodal skin eruptions : 0
# You have a continuous sneezing : 0
# You have a shivering : 0
# You have a chills : 0
# You have a joint pain : 1
# You have a stomach pain : 0
# You have a acidity : 0
# You have a ulcers on tongue : 0
# You have a muscle wasting : 0
# You have a vomiting : 0
# You have a burning micturition : 0
# You have a spotting_urination : 0
# You have a fatigue : 0
# You have a weight_gain : 0
# You have a anxiety : 0
# You have a cold_hands_and_feets : 0
# You have a mood_swings : 0
# You have a weight_loss : 0
# You have a restlessness : 0
# You have a lethargy : 0
# You have a patches_in_throat : 0
# You have a irregular_sugar_level : 0
# You have a cough : 0
# You have a high_fever : 0
# You have a sunken_eyes : 0
# You have a breathlessness : 0
# You have a sweating : 0
# You have a dehydration : 0
# You have a indigestion : 0
# You have a headache : 0
# You have a yellowish_skin : 0
# ...

# %%
final_predict = rf.predict([[input1,input2,input3,input4,input5,input6,input7,input8,input9,input10,input11,input12,input13,input14,input15,input16,input17,input18,input19,input20,input21,input22,input23,input24,input25,input26,input27,input28,input29,input30,input31,input32,input33,input34,input35,input36,input37,input38,input39,input40,input41,input42,input43,input44,input45,input46,input47,input48,input49,input50,input51,input52,input53,input54,input55,input56,input57,input58,input59,input60,input61,input62,input63,input64,input65,input66,input67,input68,input69,input70,input71,input72,input73,input74,input75,input76,input77,input78,input79,input80,input81,input82,input83,input84,input85,input86,input87,input88,input89,input90,input91,input92,input93,input94,input95,input96,input97,input98,input99,input100,input101,input102,input103,input104,input105,input106,input107,input108,input109,input110,input111,input112,input113,input114,input115,input116,input117,input118,input119,input120,input121,input122,input123,input124,input125,input126,input127,input128,input129,input130,input131,input132]])[0]
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
final_predict
# Out:
# 'Osteoarthristis'

# %%
import pickle

# Save model + feature names together
model_data = {
    "model": rf,
    "features": list(x.columns)   # symptom names
}

pickle.dump(model_data, open("model.pkl", "wb"))
