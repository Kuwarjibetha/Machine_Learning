# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\verma\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2 .csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat     the close north   sector 50   2.35         11767.0
# 1          flat      ats tourmaline  sector 109   2.30          8897.0
# 2         house      unitech espace   sector 50   7.50         34722.0
# 3         house  emaar mgf marbella   sector 66    NaN             NaN
# 4          flat          rof ananda   sector 95   0.46          6318.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1997.0  Super Built up area 1997(185.53 sq.m.)Built Up...        3
# 1  2585.0             Super Built up area 2585(240.15 sq.m.)        3
# 2  2160.0  Plot area 240(200.67 sq.m.)Built Up area: 241 ...        3
# 3     NaN                        Plot area 500(418.06 sq.m.)        5
# 4   728.0                     Carpet area: 728 (67.63 sq.m.)        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %% [markdown]
# # Price

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 2029         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 1823         house                                        independent
# 1702         house                                        independent
# 728          house                                     dlf city plots
# 1022         house                                   suncity township
# 948          house                             emaar the palm springs
# 3174         house                                        independent
# 1905         house                                 vipul tatvam villa
# 595          house                                        independent
# 438          house                                     dlf city plots
# 474          house                             luxury dlf city floors
# 1233         house                                 vipul tatvam villa
# ...

# %%
outliers.sort_values('price',ascending=False).to_csv('OUTLIERS1.csv',index=False)

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.sort_values('price_per_sqft',ascending=False).head(20)
# Out:
#      property_type                      society     sector  price  \
# 948          house       emaar the palm springs  sector 54  24.00
# 1257         house       dlf city plots phase 2  sector 25  10.00
# 707          house                  independent  sector 12   6.00
# 886          house                        ansal  sector 43   1.85
# 2979         house               uppal southend  sector 49   6.75
# 1035         house  unitech nirvana birch court  sector 50   7.10
# 488          house                  independent  sector 57   8.00
# 3153         house       dlf city plots phase 2  sector 25  10.50
# 1990         house          huda plot sector 38  sector 38   4.30
# 931          house                  independent  sector 55   1.45
# 2310         house       unitech deerwood chase  sector 50   8.45
# 1475         house                  independent  sector 54   3.75
# 2057         house                  independent  sector 38   8.00
# ...

# %%
# outliers_sqft.sort_values('price_per_sqft',ascending=False).to_csv('outliers_sqft.csv',index=False)

# %%
# After Spending some time with data i get to know that
# The Values in area columns which are less than 1000 that are in sq_yards so i have to convert it into sq_ft
# 1 sq_yards into 9sq_ft

# %%
# convert the area value inton sq_ft but only for a outlier data
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2165031417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
# here i have recalculated the the price_per_sqft only for the outliers data
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\1456879321.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
# 3150.0*26.00

# %%
outliers_sqft.sort_values('price_per_sqft',ascending=False).head(20)
# Out:
#      property_type                       society           sector  price  \
# 1702         house                   independent        sector 26  26.00
# 948          house        emaar the palm springs        sector 54  24.00
# 152          house  project housing board colony        sector 31   8.00
# 1936         house        emaar the palm springs        sector 54  14.00
# 2119         house                unitech escape        sector 50  10.80
# 1401         house                   independent        sector 25  16.00
# 2520          flat                unitech vistas        sector 70   9.00
# 728          house                dlf city plots        sector 26  26.00
# 1994         house            emaar mgf marbella        sector 66  18.00
# 1149         house            cloudnine cottages  sohna road road   5.50
# 1495         house                  malibu towne        sector 47   8.50
# 308          house                   independent        sector 26  14.75
# ...

# %%
# Now here ouer mean and median are approximately equal and max price get so reduced
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
# Now making changes in original data Frame
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2451507319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
df['price_per_sqft'].skew()
# Out:
# 2.4063837889604796

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Now i check the price_per_sqft for more than 50000
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 152          house  project housing board colony        sector 31   8.00
# 308          house                   independent        sector 26  14.75
# 728          house                dlf city plots        sector 26  26.00
# 948          house        emaar the palm springs        sector 54  24.00
# 1149         house            cloudnine cottages  sohna road road   5.50
# 1401         house                   independent        sector 25  16.00
# 1495         house                  malibu towne        sector 47   8.50
# 1702         house                   independent        sector 26  26.00
# 1936         house        emaar the palm springs        sector 54  14.00
# 1994         house            emaar mgf marbella        sector 66  18.00
# 2119         house                unitech escape        sector 50  10.80
# 2137         house                           nul        sector 28  12.50
# ...

# %%
# Total 13 rows are there whose price is more than 50000
df[df['price_per_sqft']>50000].shape
# Out:
# (13, 23)

# %%
# here i have excluded these 13 row from the data
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2451507319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
df['price_per_sqft'].skew()
# Out:
# 2.0364072843274155

# %%
df['price_per_sqft'].describe()
# Out:
# count     3647.000000
# mean     11474.143406
# std       7598.603380
# min          4.000000
# 25%       6735.000000
# 50%       8916.000000
# 75%      13383.000000
# max      50000.000000
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# # Area

# %%
# here again the crazy distribution in area column
sns.distplot(df['area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\1761899025.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
df['area'].skew()
# Out:
# 29.67273999907765

# %%
# here are few area values which is greater than 800000 sq_ft 
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
# here are only few data whouse area is greater than 100000
# and the anamoly in the data is getting this muchh bigger area in very low price
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 881           flat          hcbs sports ville  sohna road   0.35
# 1159          flat  signature global solera 2  sector 107   0.51
# 1615         house                independent   sector 50   5.00
# 2267          flat      signature the roselia   sector 95   0.45
# 3368          flat            ramsons kshitij   sector 95   0.31
#
#       price_per_sqft      area                           areaWithType  \
# 881              4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 1159             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1615           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 2267             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 3368             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 881         2         2       2       8.0         NaN  Relatively New
# ...

# %%
# here i am dropping those are whose area is greater than 100000 from the original dasta
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
# Now here i have find those values whose area is greater than 10000 because 10000 is also a very greater area
df[df['area'] > 10000].sort_values('area',ascending=False)

# After starring the data i have noticed that anamolies in the prices
# 700, 2591, 1952, 1372, 418, 2179, 1597, 3014, 70
# Out:
#      property_type                    society           sector  price  \
# 700          house                independent        sector 26  18.40
# 1643         house  ganpati heights apartment        sector 13   1.25
# 2591          flat                 rof ananda        sector 95   0.38
# 1952          flat                 rof ananda        sector 95   0.38
# 127          house      dlf city plot phase 4        sector 28  13.00
# 1372          flat              pyramid elite        sector 86   0.46
# 418           flat                 rof ananda        sector 95   0.33
# 2179          flat      signature the serenas       sohna road   0.28
# 2905         house                independent        sector 25   7.30
# 1597          flat            ramsons kshitij        sector 95   0.24
# 3014          flat                 rof ananda        sector 95   0.21
# 46           house                independent        sector 57   6.25
# ...

# %%
# dropping these anamolies from the data
df.drop(index=[700, 2591, 1952, 1372, 418, 2179, 1597, 3014, 70], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 1643         house  ganpati heights apartment        sector 13   1.25
# 127          house      dlf city plot phase 4        sector 28  13.00
# 2905         house                independent        sector 25   7.30
# 46           house                independent        sector 57   6.25
# 3168         house                independent        sector 43   5.50
# 3617          flat                 godrej air        sector 85   2.50
# 2753         house       unitech aspen greens        sector 50   6.95
# 89            flat                godrej icon       sector 88a   1.75
# 1823         house                independent        sector 43  27.50
# 828           flat             m3m golfestate        sector 65  13.20
# 2209         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 1643           151.0  82781.0
# 127           1992.0  65261.0
# 2905          1560.0  46795.0
# ...

# %%
# df[df['area'] > 10000].sort_values('area',ascending=False)[['super_built_up_area','built_up_area','carpet_area']]

# %%
# these all are the data errors

df.loc[1643,'area'] = 115*9 # Built_up_area (here converting square yard into sq_ft)
df.loc[127,'area'] = 7250 # Carpet_area
df.loc[2905,'area'] = 5800 # Builtup area
df.loc[46,'area'] = 2660  # Built up area
df.loc[3168,'area'] = 2850 # Built up area
df.loc[3617,'area'] = 1812 # Carpet area
df.loc[2753,'area'] = 2160 # Built_up_area
df.loc[89,'area'] = 1175 # Carpet_area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
# Now it is showing more realistic number
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 406          house                  independent   sector 54   5.00
# 3428         house                  independent   sector 43   4.50
# 2626         house                  independent  sector 17a   3.93
# 2766         house                  independent  sector 17a   3.87
# 2996         house                  independent   sector 54   5.50
# 964          house                private house   sector 55   7.05
# 2641         house                  independent   sector 11   4.50
# 438          house               dlf city plots   sector 26  20.00
# 474          house       luxury dlf city floors   sector 26  20.00
# 1550         house                  independent   sector 43  13.50
# 3151         house                  independent   sector 40  12.00
# 2772         house                  independent   sector 56  12.39
# 1296         house                  independent   sector 55   9.19
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 571          house  adani brahma samsara  sector 60  18.02         28200.0
# 581          house           independent  sector 24  11.00         28902.0
# 3139         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 571   6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 581   3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 3139  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 571         12      3+       3.0  North-East  Relatively New
# 581         11      3+       3.0        East    Old Property
# 3139        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type          society           sector  price  price_per_sqft  \
# 0          flat  the close north        sector 50   2.35         11767.0
# 1          flat   ats tourmaline       sector 109   2.30          8897.0
# 2         house   unitech espace        sector 50   7.50         34722.0
# 4          flat       rof ananda        sector 95   0.46          6318.0
# 5         house        prem kunj  sohna road road   0.50          7407.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1997.0  Super Built up area 1997(185.53 sq.m.)Built Up...        3
# 1  2585.0             Super Built up area 2585(240.15 sq.m.)        3
# 2  2160.0  Plot area 240(200.67 sq.m.)Built Up area: 241 ...        3
# 4   728.0                     Carpet area: 728 (67.63 sq.m.)        2
# 5   675.0  Plot area 675(62.71 sq.m.)Built Up area: 725 s...        5
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1983          flat       krrish provence estate  gwal pahari    7.5
# 2230          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 1983          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 2230          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1983        5         6      3+      23.0  North-East  Relatively New
# 2230        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1983              10000.0            NaN          NaN           0
# 2230               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 1823         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1823  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1823  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1823          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 1823                2            42

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 828           flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 3617          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 828   Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 3617  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 828        North  Moderately Old                  NaN            NaN
# 3617  North-East       Undefined                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 828       11000.0           0             1           0           0       0
# 3617      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[3617,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#     property_type         society     sector  price  price_per_sqft     area  \
# 828          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                            areaWithType  bedRoom  bathroom balcony  floorNum  \
# 828  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#     facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 828  North  Moderately Old                  NaN            NaN      11000.0
#
#      study room  servant room  store room  pooja room  others  \
# 828           0             1           0           0       0
#
#      furnishing_type  luxury_score
# 828                0            60

# %%
df.head()
# Out:
#   property_type          society           sector  price  price_per_sqft  \
# 0          flat  the close north        sector 50   2.35         11767.0
# 1          flat   ats tourmaline       sector 109   2.30          8897.0
# 2         house   unitech espace        sector 50   7.50         34722.0
# 4          flat       rof ananda        sector 95   0.46          6318.0
# 5         house        prem kunj  sohna road road   0.50          7407.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1997.0  Super Built up area 1997(185.53 sq.m.)Built Up...        3
# 1  2585.0             Super Built up area 2585(240.15 sq.m.)        3
# 2  2160.0  Plot area 240(200.67 sq.m.)Built Up area: 241 ...        3
# 4   728.0                     Carpet area: 728 (67.63 sq.m.)        2
# 5   675.0  Plot area 675(62.71 sq.m.)Built Up area: 725 s...        5
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %% [markdown]
# # luxury_Score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (3588, 23)

# %%
# i was thinking to re calculate the price_per_sqft because we have made some changes in area values. 
# so because of that it may be some changes in price_per_sqft

# %%
# here i am re calculating the price_per_sqft

df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type          society           sector  price  price_per_sqft  \
# 0          flat  the close north        sector 50   2.35         11768.0
# 1          flat   ats tourmaline       sector 109   2.30          8897.0
# 2         house   unitech espace        sector 50   7.50         34722.0
# 4          flat       rof ananda        sector 95   0.46          6319.0
# 5         house        prem kunj  sohna road road   0.50          7407.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1997.0  Super Built up area 1997(185.53 sq.m.)Built Up...        3
# 1  2585.0             Super Built up area 2585(240.15 sq.m.)        3
# 2  2160.0  Plot area 240(200.67 sq.m.)Built Up area: 241 ...        3
# 4   728.0                     Carpet area: 728 (67.63 sq.m.)        2
# 5   675.0  Plot area 675(62.71 sq.m.)Built Up area: 725 s...        5
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\verma\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: >

# %%
# here i have notice some data errors between area and bedrooms because i lesser area so many bedrooms are not possible
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 595          house                   independent   sector 26   20.0
# 958          house                dlf city plots   sector 26   19.0
# 1201         house                   independent  sector 105    9.9
# 2633         house                   independent   sector 28   12.0
# 2640         house                   independent   sector 55    5.0
# 2944         house  sushant lok 1 builder floors   sector 43   13.0
# 3085         house                   independent   sector 26   19.0
# 3193         house                   independent   sector 25   13.0
# 3644         house                   independent   sector 43    9.5
#
#       price_per_sqft    area  \
# 595          44444.0  4500.0
# 958          42054.0  4518.0
# 1201         49500.0  2000.0
# 2633         42194.0  2844.0
# 2640         44444.0  1125.0
# 2944         48148.0  2700.0
# 3085         42222.0  4500.0
# 3193         45710.0  2844.0
# ...

# %%
# Here i am finding the ratio between area & bedroom so that i am able to detect the data errors 
# fornthat i have selected the fair price_per_sqft value
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 250.5

# %%
df[(df['area']/df['bedRoom'])<250]
# Out:
#      property_type        society                      sector  price  \
# 5            house      prem kunj             sohna road road   0.50
# 56            flat  prime habitat                  sector 99a   0.27
# 58           house     huda floor                   sector 38   4.00
# 65           house    independent                  sector 10a   3.60
# 88           house        my home                new sector 2   0.34
# ...            ...            ...                         ...    ...
# 3721         house    independent  sector 3 phase 3 extension   0.50
# 3728         house       ss omnia                   sector 86   0.42
# 3739          flat     mvn athens                  sohna road   0.25
# 3771         house    independent                    sector 7   0.90
# 3773          flat     mvn athens                  sohna road   0.25
#
#       price_per_sqft    area  \
# 5             7407.0   675.0
# 56            6054.0   446.0
# 58           22222.0  1800.0
# ...

# %%
len(df[(df['area']/df['bedRoom'])<250])
# Out:
# 185

# %%
df['area_room']=df['area']/df['bedRoom']
df
# Out:
#      property_type                 society           sector  price  \
# 0             flat         the close north        sector 50   2.35
# 1             flat          ats tourmaline       sector 109   2.30
# 2            house          unitech espace        sector 50   7.50
# 4             flat              rof ananda        sector 95   0.46
# 5            house               prem kunj  sohna road road   0.50
# ...            ...                     ...              ...    ...
# 3795          flat    vatika emilia floors        sector 83   0.60
# 3796          flat  unitech the residences        sector 33   1.35
# 3798          flat    shree vardhman flora        sector 90   0.66
# 3801          flat  bestech park view city        sector 49   2.90
# 3802          flat     oriental valley chs        sector 9a   1.50
#
#       price_per_sqft    area  \
# 0            11768.0  1997.0
# 1             8897.0  2585.0
# 2            34722.0  2160.0
# 4             6319.0   728.0
# ...

# %%
df.sort_values(by='area_room')
# Out:
#      property_type                          society  \
# 1499         house                      independent
# 132          house  ashok vihar phase iii extension
# 886          house                            ansal
# 1365         house                      independent
# 2257         house                      independent
# ...            ...                              ...
# 2616          flat                  ramsons kshitij
# 2606         house                      independent
# 2209         house                      independent
# 793          house                      independent
# 1012          flat            pivotal riddhi siddhi
#
#                           sector  price  price_per_sqft     area  \
# 1499                   sector 28   0.75         20833.0    360.0
# 132   sector 3 phase 3 extension   0.40          8889.0    450.0
# 886                    sector 43   1.85         34259.0    540.0
# 1365                  sector 105   0.60         11111.0    540.0
# ...

# %%
360/7
# Out:
# 51.42857142857143

# %%
sns.lmplot(x='area',y='bedRoom',data=df);

# %%
# here i am dropping those data point which are data errors
df = df[df['area_room']>100]

# %%
# this also can be a data errors
outliers_df = df[(df['area_room']<250) & (df['bedRoom']>3)]
outliers_df
# Out:
#      property_type                  society            sector  price  \
# 5            house                prem kunj   sohna road road   0.50
# 58           house               huda floor         sector 38   4.00
# 65           house              independent        sector 10a   3.60
# 100          house  iffco nagar and 17b rwa         sector 17   2.98
# 129          house              independent         sector 47   4.60
# ...            ...                      ...               ...    ...
# 3592         house              independent  sector 3 phase 2   0.85
# 3615         house              independent         sector 38   2.10
# 3659         house           not applicable          sector 4   0.75
# 3689         house              independent           manesar   1.10
# 3771         house              independent          sector 7   0.90
#
#       price_per_sqft    area  \
# 5             7407.0   675.0
# 58           22222.0  1800.0
# 65           19608.0  1836.0
# ...

# %%
# here i am finding the no of rooms per floor
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
outliers_df
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\1231268247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
#      property_type                  society            sector  price  \
# 5            house                prem kunj   sohna road road   0.50
# 58           house               huda floor         sector 38   4.00
# 65           house              independent        sector 10a   3.60
# 100          house  iffco nagar and 17b rwa         sector 17   2.98
# 129          house              independent         sector 47   4.60
# ...            ...                      ...               ...    ...
# ...

# %%
df.update(outliers_df)

# %%
# again i am calculating the ratio area room because we have made changes in the bedroom value
df['area_room']=df['area']/df['bedRoom']
df
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_20688\96610705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room']=df['area']/df['bedRoom']
#      property_type                 society           sector  price  \
# 0             flat         the close north        sector 50   2.35
# 1             flat          ats tourmaline       sector 109   2.30
# 2            house          unitech espace        sector 50   7.50
# 4             flat              rof ananda        sector 95   0.46
# 5            house               prem kunj  sohna road road   0.50
# ...            ...                     ...              ...    ...
# 3795          flat    vatika emilia floors        sector 83   0.60
# ...

# %%
# there are 13 data points
df[(df['area_room']<250) & (df['bedRoom']>4)].shape
# Out:
# (13, 24)

# %%
df.shape
# Out:
# (3568, 24)

# %%
# here i am excluding these 13 rows from the data
df = df[~((df['area_room']<250) & (df['bedRoom']>4))]
df
# Out:
#      property_type                 society           sector  price  \
# 0             flat         the close north        sector 50   2.35
# 1             flat          ats tourmaline       sector 109   2.30
# 2            house          unitech espace        sector 50   7.50
# 4             flat              rof ananda        sector 95   0.46
# 5            house               prem kunj  sohna road road   0.50
# ...            ...                     ...              ...    ...
# 3795          flat    vatika emilia floors        sector 83   0.60
# 3796          flat  unitech the residences        sector 33   1.35
# 3798          flat    shree vardhman flora        sector 90   0.66
# 3801          flat  bestech park view city        sector 49   2.90
# 3802          flat     oriental valley chs        sector 9a   1.50
#
#       price_per_sqft    area  \
# 0            11768.0  1997.0
# 1             8897.0  2585.0
# 2            34722.0  2160.0
# 4             6319.0   728.0
# ...

# %%
sns.lmplot(x='area',y='bedRoom',data=df);

# %%
df.to_csv('gurgaon_properties_outliers_treated.csv',index=False)
